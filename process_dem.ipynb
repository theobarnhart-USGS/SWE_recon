# %%
state = 'mt'

# %%
import rasterio as rs

# %%
fl = './data/dem/%s/%s_dem_180m.tiff'%(state,state)

# %%
with rs.open(fl) as ds:
        dem = np.array(ds.read(1),dtype=np.float)
        nd = ds.get_nodatavals() 
        dem[dem==nd] = np.NaN

# %%
np.save('./data/%s_dem_180m.npy'%(state),dem)

# %%
plt.imshow(dem)
